# %% [markdown]
# This notebook calculates the coverage of Wikidata Lexemes regarding a given Wikipedia language edition.
#
# All code and text on this page is double licensed under CC0 and into the Public Domain.
#
# First let's download the cleaned-up data from https://download.wmcloud.org/corpora
#
# This data has been extracted from the language models published at https://www.tensorflow.org/datasets/catalog/wiki40b (see https://www.aclweb.org/anthology/2020.lrec-1.297/ for the language models).

# %%
languages = [
    'ar', 'bg', 'ca', 'cs', 'da', 'de', 'el', 'en', 'es', 'et',
    'fa', 'fi', 'fr', 'he', 'hi', 'hr', 'hu', 'id', 'it', # 'ja',
    'ko', 'lt', 'lv', 'ms', 'nl', 'no', 'pl', 'pt', 'ro', 'ru',
    'sk', 'sl', 'sr', 'sv', 'th', 'tl', 'tr', 'uk', 'vi',
    # 'zh-cn', 'zh-tw'
]
# languages = [ 'lv' ]

import urllib.request
import os.path

for language in languages:
    filename = language + '.txt.gz'
    if os.path.exists('corpus-' + filename):
        print('Already downloaded ' + language)
        continue
    url = 'https://download.wmcloud.org/corpora/' + filename
    urllib.request.urlretrieve(url, 'corpus-' + filename)
    print('Downloaded ' + language)
# Out:
# Already downloaded ar
# Already downloaded bg
# Already downloaded ca
# Already downloaded cs
# Already downloaded da
# Already downloaded de
# Already downloaded el
# Already downloaded en
# Already downloaded es
# Already downloaded et
# Already downloaded fa
# Already downloaded fi
# Already downloaded fr
# Already downloaded he
# Already downloaded hi
# Already downloaded hr
# Already downloaded hu
# Already downloaded id
# Already downloaded it
# Already downloaded ko
# Already downloaded lt
# Already downloaded lv
# Already downloaded ms
# Already downloaded nl
# Already downloaded no
# Already downloaded pl
# Already downloaded pt
# Already downloaded ro
# Already downloaded ru
# Already downloaded sk
# Already downloaded sl
# Already downloaded sr
# Already downloaded sv
# Already downloaded th
# Already downloaded tl
# Already downloaded tr
# Already downloaded uk
# Already downloaded vi

# %% [markdown]
# We create a wordlist from the downloaded files.

# %%
import gzip
import json

for language in languages:
    wordlist = {}
    print('Reading ' + language)
        
    errorcount = 0
    tokencount = 0
    
    corpusfile = 'corpus-' + language + '.txt.gz'
    linecount = 0
    first = True
    for line in gzip.open(corpusfile, 'r'):
        linecount += 1
        if linecount % 100000 == 0:
            print('{:,} articles processed'.format(linecount))
        for c in [
                b'.', b',', b'_', b'(', b')', b'=', b'"',
                b'\xe2\x80\x9e', b'\xe2\x80\x9f', b'\xe0\xa5\xa4', b'\xe0\xa5\xa5'
        ]:
            line = line.replace(c, b' ')
        words = line.split()
        for word in words:
            tokencount += 1
            try:
                word = word.decode('utf-8')
            except UnicodeDecodeError as e:
                # print(e)
                # print(word)
                # print('')
                errorcount += 1
                continue
            if word in ['', 'NEWLINE']:
                continue
            if word.isdigit():
                continue
            word = word.lower()
            if word not in wordlist:
                wordlist[word] = 0
            wordlist[word] += 1
    
    output = open('wordlist-' + language + '.txt', 'w')
    
    tencount = 0
    tentokencount = 0
    for l in sorted(wordlist.items(), reverse=True, key=lambda x: x[1]):
        if l[1] > 10:
            tencount += 1
            tentokencount += l[1]
            output.write(l[0] + ' ' + str(l[1]) + '\n')
    output.close()
    
    with open('meta-' + language + '.txt', 'w') as output:
        json.dump({
            'corpus': 'wiki40b',
            'numberOfFormsInWiki': len(wordlist),
            'numberOfFormsInWikiTen': tencount,
            'numberOfTokens': tokencount,
            'numberOfTokensTen': tentokencount,
            'unicodeErrors': errorcount
        }, output, indent=4)
    print('Read {} with {:,} different word forms, {:,} with 10+ in {:,} words ({:,} errors)'.format(language, len(wordlist), tencount, tokencount, errorcount))
# Out:
# Reading ar
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# Read ar with 2,460,454 different word forms, 248,979 with 10+ in 77,178,818 words (117,326 errors)
# Reading bg
# 100,000 articles processed
# 200,000 articles processed
# Read bg with 1,011,156 different word forms, 124,250 with 10+ in 36,705,914 words (31,557 errors)
# Reading ca
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# Read ca with 1,589,331 different word forms, 186,266 with 10+ in 117,262,711 words (91,911 errors)
# Reading cs
# 100,000 articles processed
# 200,000 articles processed
# 600,000 articles processed
# Read cs with 2,208,808 different word forms, 273,087 with 10+ in 80,899,609 words (181 errors)
# Reading da
# 100,000 articles processed
# 200,000 articles processed
# Read da with 1,172,893 different word forms, 113,223 with 10+ in 34,553,159 words (21,205 errors)
# Reading de
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# 1,200,000 articles processed
# 1,300,000 articles processed
# 1,400,000 articles processed
# 1,500,000 articles processed
# 1,600,000 articles processed
# 1,700,000 articles processed
# 1,800,000 articles processed
# 1,900,000 articles processed
# 2,000,000 articles processed
# 2,100,000 articles processed
# 2,200,000 articles processed
# 2,300,000 articles processed
# 2,400,000 articles processed
# 2,500,000 articles processed
# 2,600,000 articles processed
# 2,700,000 articles processed
# 2,800,000 articles processed
# 2,900,000 articles processed
# 3,000,000 articles processed
# 3,100,000 articles processed
# 3,200,000 articles processed
# 3,300,000 articles processed
# 3,400,000 articles processed
# 3,500,000 articles processed
# 3,600,000 articles processed
# 3,700,000 articles processed
# 3,800,000 articles processed
# 3,900,000 articles processed
# 4,000,000 articles processed
# 4,100,000 articles processed
# 4,200,000 articles processed
# 4,300,000 articles processed
# 4,400,000 articles processed
# 4,500,000 articles processed
# 4,600,000 articles processed
# 4,700,000 articles processed
# 4,800,000 articles processed
# 4,900,000 articles processed
# Read de with 10,335,873 different word forms, 1,073,173 with 10+ in 648,487,382 words (574,417 errors)
# Reading el
# 100,000 articles processed
# 200,000 articles processed
# Read el with 1,157,097 different word forms, 132,278 with 10+ in 44,089,840 words (30,626 errors)
# Reading en
# 100,000 articles processed
# 3,600,000 articles processed
# 3,700,000 articles processed
# 3,800,000 articles processed
# 3,900,000 articles processed
# 4,000,000 articles processed
# 4,100,000 articles processed
# 4,200,000 articles processed
# 4,300,000 articles processed
# 4,400,000 articles processed
# 4,500,000 articles processed
# 4,600,000 articles processed
# 4,700,000 articles processed
# 4,800,000 articles processed
# 4,900,000 articles processed
# 5,000,000 articles processed
# 5,100,000 articles processed
# 5,200,000 articles processed
# 5,300,000 articles processed
# 5,400,000 articles processed
# 5,500,000 articles processed
# 5,600,000 articles processed
# 5,700,000 articles processed
# 5,800,000 articles processed
# 5,900,000 articles processed
# 6,000,000 articles processed
# 6,100,000 articles processed
# 6,200,000 articles processed
# 6,300,000 articles processed
# 6,400,000 articles processed
# 6,500,000 articles processed
# 6,600,000 articles processed
# 6,700,000 articles processed
# 6,800,000 articles processed
# 6,900,000 articles processed
# 7,000,000 articles processed
# 7,100,000 articles processed
# 7,200,000 articles processed
# 7,300,000 articles processed
# 7,400,000 articles processed
# 7,500,000 articles processed
# 7,600,000 articles processed
# 7,700,000 articles processed
# 7,800,000 articles processed
# 7,900,000 articles processed
# 8,000,000 articles processed
# 8,100,000 articles processed
# 8,200,000 articles processed
# 8,300,000 articles processed
# 8,400,000 articles processed
# 8,500,000 articles processed
# 8,600,000 articles processed
# 8,700,000 articles processed
# 8,800,000 articles processed
# 8,900,000 articles processed
# 9,000,000 articles processed
# 9,100,000 articles processed
# 9,200,000 articles processed
# 9,300,000 articles processed
# 9,400,000 articles processed
# 9,500,000 articles processed
# 9,600,000 articles processed
# 9,700,000 articles processed
# 9,800,000 articles processed
# 9,900,000 articles processed
# Read en with 9,696,397 different word forms, 1,072,926 with 10+ in 1,593,574,695 words (1,197,189 errors)
# Reading es
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# 1,200,000 articles processed
# 1,300,000 articles processed
# 1,400,000 articles processed
# 1,500,000 articles processed
# 1,600,000 articles processed
# 1,700,000 articles processed
# 1,800,000 articles processed
# 1,900,000 articles processed
# 2,000,000 articles processed
# 2,100,000 articles processed
# 2,200,000 articles processed
# 2,300,000 articles processed
# 2,400,000 articles processed
# 2,500,000 articles processed
# Read es with 3,772,035 different word forms, 416,675 with 10+ in 431,776,895 words (167,592 errors)
# Reading et
# 100,000 articles processed
# 200,000 articles processed
# Read et with 1,409,648 different word forms, 125,437 with 10+ in 20,806,878 words (59,516 errors)
# Reading fa
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# Read fa with 1,108,572 different word forms, 104,967 with 10+ in 47,807,711 words (102,935 errors)
# Reading fi
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# Read fi with 3,258,419 different word forms, 282,727 with 10+ in 55,551,451 words (100,377 errors)
# Reading fr
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# 1,200,000 articles processed
# 1,300,000 articles processed
# 1,400,000 articles processed
# 1,500,000 articles processed
# 1,600,000 articles processed
# 1,700,000 articles processed
# 1,800,000 articles processed
# 1,900,000 articles processed
# 2,000,000 articles processed
# 2,100,000 articles processed
# 2,200,000 articles processed
# 2,300,000 articles processed
# 2,400,000 articles processed
# 2,500,000 articles processed
# 2,600,000 articles processed
# 2,700,000 articles processed
# 2,800,000 articles processed
# 2,900,000 articles processed
# 3,000,000 articles processed
# 3,100,000 articles processed
# 3,200,000 articles processed
# 3,300,000 articles processed
# 3,400,000 articles processed
# 3,500,000 articles processed
# 3,600,000 articles processed
# Read fr with 4,827,059 different word forms, 540,009 with 10+ in 502,275,968 words (191,991 errors)
# Reading he
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# Read he with 1,817,743 different word forms, 255,342 with 10+ in 82,891,727 words (73,293 errors)
# Reading hi
# 100,000 articles processed
# Read hi with 673,690 different word forms, 54,935 with 10+ in 20,451,145 words (11,556 errors)
# Reading hr
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# Read hr with 1,127,391 different word forms, 137,082 with 10+ in 32,054,016 words (32,315 errors)
# Reading hu
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# Read hu with 3,083,148 different word forms, 281,622 with 10+ in 72,448,401 words (111,815 errors)
# Reading id
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# Read id with 944,165 different word forms, 103,375 with 10+ in 43,420,176 words (71,308 errors)
# Reading it
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# 1,200,000 articles processed
# 1,300,000 articles processed
# 1,400,000 articles processed
# 1,500,000 articles processed
# 1,600,000 articles processed
# 1,700,000 articles processed
# 1,800,000 articles processed
# 1,900,000 articles processed
# 2,000,000 articles processed
# Read it with 2,848,514 different word forms, 370,267 with 10+ in 301,350,717 words (40,871 errors)
# Reading ko
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# Read ko with 4,190,852 different word forms, 290,353 with 10+ in 41,900,662 words (60,552 errors)
# Reading lt
# 100,000 articles processed
# Read lt with 879,219 different word forms, 96,570 with 10+ in 15,629,523 words (4,536 errors)
# Reading lv
# Read lv with 491,137 different word forms, 60,809 with 10+ in 9,517,646 words (20,605 errors)
# Reading ms
# 100,000 articles processed
# Read ms with 484,874 different word forms, 52,582 with 10+ in 17,771,263 words (19,846 errors)
# Reading nl
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# Read nl with 2,405,180 different word forms, 267,554 with 10+ in 140,614,831 words (151,119 errors)
# Reading no
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# Read no with 1,743,393 different word forms, 158,509 with 10+ in 54,812,841 words (58,052 errors)
# Reading pl
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# Read pl with 2,614,147 different word forms, 348,473 with 10+ in 130,167,064 words (197,514 errors)
# Reading pt
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# 400,000 articles processed
# 500,000 articles processed
# 600,000 articles processed
# 700,000 articles processed
# 800,000 articles processed
# 900,000 articles processed
# 1,000,000 articles processed
# 1,100,000 articles processed
# Read pt with 1,942,459 different word forms, 227,825 with 10+ in 167,875,344 words (201,731 errors)
# Reading ro
# 100,000 articles processed
# 200,000 articles processed
# 300,000 articles processed
# Read ro with 1,058,959 different word forms, 123,773 with 10+ in 44,646,263 words (26,452 errors)
# Reading ru

# %% [markdown]
# Now that we have the wordlists, let's download the Lexemes from Wikidata using the latest dumps.

# %%
lexemesfile = 'latest-lexemes.json.gz'
if os.path.exists(lexemesfile):
    print('Already downloaded')
else:
    url = 'https://dumps.wikimedia.org/wikidatawiki/entities/' + lexemesfile
    urllib.request.urlretrieve(url, lexemesfile)
    print('Downloaded lexemes')
# Out:
# Downloaded lexemes

# %% [markdown]
# Let's get all the Forms attested in the Lexemes and store them as a formlist.

# %%
import gzip
import json

count = 0

qmap = {
    'ar' : 'Q13955',
    'bg' : 'Q7918',
    'ca' : 'Q7026',
    'cs' : 'Q9056',
    'da' : 'Q9035',
    'de' : 'Q188',
    'el' : 'Q9129',
    'en' : 'Q1860',
    'es' : 'Q1321',
    'et' : 'Q9072',
    'fa' : 'Q9168',
    'fi' : 'Q1412',
    'fr' : 'Q150',
    'he' : 'Q9288',
    'hi' : 'Q11051',
    'hr' : 'Q6654',
    'hu' : 'Q9067',
    'id' : 'Q9240',
    'it' : 'Q652',
#    'ja' : 'Q5287',
    'ko' : 'Q9176',
    'lt' : 'Q9083',
    'lv' : 'Q9078',
    'ms' : 'Q9237',
    'nl' : 'Q7411',
    'no' : 'Q9043',
    'pl' : 'Q809',
    'pt' : 'Q5146',
    'ro' : 'Q7913',
    'ru' : 'Q7737',
    'sk' : 'Q9058',
    'sl' : 'Q9063',
    'sr' : 'Q9299',
    'sv' : 'Q9027',
    'th' : 'Q9217',
    'tl' : 'Q34057',
    'tr' : 'Q256',
    'uk' : 'Q8798',
    'vi' : 'Q9199',
#    'zh-cn' : 'Q24841726',
#    'zh-tw' : 'Q262828'
}
mapq = {}
for k in qmap:
    mapq[qmap[k]] = k

outputs = {}
for language in languages:
    outputs[language] = open('formlist-' + language + '.txt', 'w')

errorcount = 0
dictcount = 0
    
for line in gzip.open('latest-lexemes.json.gz'):
    count += 1
    line = line.decode('utf-8').strip()
    if len(line) < 2: continue
    if line[-1] == ',':
        line = line[:-1]
    lexeme = json.loads(line)
    if lexeme['language'] in mapq:
        dictcount += 1
        for form in lexeme['forms']:
            try:
                outputs[mapq[lexeme['language']]].write(form['representations'][mapq[lexeme['language']]]['value'] + '\n')
            except:
                errorcount += 1
                print(errorcount)
                print(lexeme['id'])
                print(lexeme['lemmas'])
                print('')

for language in languages:
    outputs[language].close()

print('{:,} Lexemes total, {:,} used'.format(count, dictcount))
# Out:
# 1
# L2729
# {'ar': {'language': 'ar', 'value': 'فعل'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'فِعْل'}}
#
# 2
# L2729
# {'ar': {'language': 'ar', 'value': 'فعل'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'فِعْل'}}
#
# 3
# L11565
# {'pt': {'language': 'pt', 'value': 'cachorro'}}
#
# 4
# L11565
# {'pt': {'language': 'pt', 'value': 'cachorro'}}
#
# 5
# L11565
# {'pt': {'language': 'pt', 'value': 'cachorro'}}
#
# 6
# L11565
# {'pt': {'language': 'pt', 'value': 'cachorro'}}
#
# 7
# L64262
# {'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בַּיִת'}, 'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בית'}}
#
# 8
# L64262
# {'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בַּיִת'}, 'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בית'}}
#
# 9
# L295573
# {'ja': {'language': 'ja', 'value': '明かり'}, 'ja-hira': {'language': 'ja-hira', 'value': 'あかり'}}
#
# 10
# L346685
# {'fr': {'language': 'fr', 'value': 'agrément'}}
#
# 11
# L402496
# {'fr': {'language': 'fr', 'value': 'garde-magasin'}}
#
# 12
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 13
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 14
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 15
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 16
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 17
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 18
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 19
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 20
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 21
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 22
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 23
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 24
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 25
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 26
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 27
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 28
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 29
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 30
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 31
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 32
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 33
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 34
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 35
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 36
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 37
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 38
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 39
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 40
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 41
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 42
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 43
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 44
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 45
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 46
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 47
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 48
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 49
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 50
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 51
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 52
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 53
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 54
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 55
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 56
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 57
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 58
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 59
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 60
# L695
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שמש'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁמֶשׁ'}}
#
# 61
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 62
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 63
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 64
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 65
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 66
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 67
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 68
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 69
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 70
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 71
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 72
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 73
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 74
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 75
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 76
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 77
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 78
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 79
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 80
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 81
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 82
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 83
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 84
# L7375
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אצטרובל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִצְטְרֻבָּל'}}
#
# 85
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 86
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 87
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 88
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 89
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 90
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 91
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 92
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 93
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 94
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 95
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 96
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 97
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 98
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 99
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 100
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 101
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 102
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 103
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 104
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 105
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 106
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 107
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 108
# L7378
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'סדנה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'סַדְנָה'}}
#
# 109
# L18891
# {'fr': {'language': 'fr', 'value': 'aliment'}}
#
# 110
# L28561
# {'fr': {'language': 'fr', 'value': 'chauve-souris'}, 'fr-x-Q486561': {'language': 'fr-x-Q486561', 'value': 'chauvesouris'}}
#
# 111
# L28561
# {'fr': {'language': 'fr', 'value': 'chauve-souris'}, 'fr-x-Q486561': {'language': 'fr-x-Q486561', 'value': 'chauvesouris'}}
#
# 112
# L43388
# {'pt': {'language': 'pt', 'value': 'ela'}}
#
# 113
# L43388
# {'pt': {'language': 'pt', 'value': 'ela'}}
#
# 114
# L43388
# {'pt': {'language': 'pt', 'value': 'ela'}}
#
# 115
# L43388
# {'pt': {'language': 'pt', 'value': 'ela'}}
#
# 116
# L346563
# {'fr': {'language': 'fr', 'value': 'argument'}}
#
# 117
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 118
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 119
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 120
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 121
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 122
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 123
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 124
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 125
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 126
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 127
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 128
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 129
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 130
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 131
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 132
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 133
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 134
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 135
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 136
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 137
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 138
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 139
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 140
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 141
# L2266
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'ציר'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'צִיר'}}
#
# 142
# L3002
# {'en': {'language': 'en', 'value': 'out'}}
#
# 143
# L9361
# {'fr': {'language': 'fr', 'value': 'paraître'}}
#
# 144
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 145
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 146
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 147
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 148
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 149
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 150
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 151
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 152
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 153
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 154
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 155
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 156
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 157
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 158
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 159
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 160
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 161
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 162
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 163
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 164
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 165
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 166
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 167
# L12374
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'מזל'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'מַזָּל'}}
#
# 168
# L16428
# {'fr': {'language': 'fr', 'value': 'avertissement'}}
#
# 169
# L204330
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אבטח'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אִבְטֵחַ'}}
#
# 170
# L291517
# {'fr': {'language': 'fr', 'value': 'affluent'}}
#
# 171
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 172
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 173
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 174
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 175
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 176
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 177
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 178
# L18
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חי'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חַי'}}
#
# 179
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 180
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 181
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 182
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 183
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 184
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 185
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 186
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 187
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 188
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 189
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 190
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 191
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 192
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 193
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 194
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 195
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 196
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 197
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 198
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 199
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 200
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 201
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 202
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 203
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 204
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 205
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 206
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 207
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 208
# L415
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'כתב'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'כַּתָּב'}}
#
# 209
# L2456
# {'es-419': {'language': 'es-419', 'value': 'pijul'}}
#
# 210
# L2728
# {'ar': {'language': 'ar', 'value': 'اسم'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'اِسْم'}}
#
# 211
# L2728
# {'ar': {'language': 'ar', 'value': 'اسم'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'اِسْم'}}
#
# 212
# L2728
# {'ar': {'language': 'ar', 'value': 'اسم'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'اِسْم'}}
#
# 213
# L3649
# {'fr': {'language': 'fr', 'value': 'chapitre'}}
#
# 214
# L3649
# {'fr': {'language': 'fr', 'value': 'chapitre'}}
#
# 215
# L9747
# {'fr': {'language': 'fr', 'value': 'âme'}}
#
# 216
# L24367
# {'en': {'language': 'en', 'value': 'Hong Kong'}}
#
# 217
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 218
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 219
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 220
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 221
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 222
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 223
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 224
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 225
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 226
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 227
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 228
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 229
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 230
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 231
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 232
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 233
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 234
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 235
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 236
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 237
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 238
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 239
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 240
# L75902
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפקט'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֵפֶקְט'}}
#
# 241
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 242
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 243
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 244
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 245
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 246
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 247
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 248
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 249
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 250
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 251
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 252
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 253
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 254
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 255
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 256
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 257
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 258
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 259
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 260
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 261
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 262
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 263
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 264
# L75914
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אפרכסת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אֲפַרְכֶּסֶת'}}
#
# 265
# L298576
# {'en': {'language': 'en', 'value': 'colorist'}}
#
# 266
# L298576
# {'en': {'language': 'en', 'value': 'colorist'}}
#
# 267
# L330698
# {'en': {'language': 'en', 'value': 'yogurt'}, 'en-ca': {'language': 'en-ca', 'value': 'yogurt'}, 'en-gb': {'language': 'en-gb', 'value': 'yogurt'}}
#
# 268
# L330698
# {'en': {'language': 'en', 'value': 'yogurt'}, 'en-ca': {'language': 'en-ca', 'value': 'yogurt'}, 'en-gb': {'language': 'en-gb', 'value': 'yogurt'}}
#
# 269
# L330698
# {'en': {'language': 'en', 'value': 'yogurt'}, 'en-ca': {'language': 'en-ca', 'value': 'yogurt'}, 'en-gb': {'language': 'en-gb', 'value': 'yogurt'}}
#
# 270
# L330698
# {'en': {'language': 'en', 'value': 'yogurt'}, 'en-ca': {'language': 'en-ca', 'value': 'yogurt'}, 'en-gb': {'language': 'en-gb', 'value': 'yogurt'}}
#
# 271
# L330698
# {'en': {'language': 'en', 'value': 'yogurt'}, 'en-ca': {'language': 'en-ca', 'value': 'yogurt'}, 'en-gb': {'language': 'en-gb', 'value': 'yogurt'}}
#
# 272
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 273
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 274
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 275
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 276
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 277
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 278
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 279
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 280
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 281
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 282
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 283
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 284
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 285
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 286
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 287
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 288
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 289
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 290
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 291
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 292
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 293
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 294
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 295
# L91
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'חגיגה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'חֲגִיגָה'}}
#
# 296
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 297
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 298
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 299
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 300
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 301
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 302
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 303
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 304
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 305
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 306
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 307
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 308
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 309
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 310
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 311
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 312
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 313
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 314
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 315
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 316
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 317
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 318
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 319
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 320
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 321
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 322
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 323
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 324
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 325
# L2287
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'בירה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'בִּירָה'}}
#
# 326
# L2726
# {'ar': {'language': 'ar', 'value': 'جملة'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'جُمْلَة'}}
#
# 327
# L2726
# {'ar': {'language': 'ar', 'value': 'جملة'}, 'ar-x-Q775724': {'language': 'ar-x-Q775724', 'value': 'جُمْلَة'}}
#
# 328
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 329
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 330
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 331
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 332
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 333
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 334
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 335
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 336
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 337
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 338
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 339
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 340
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 341
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 342
# L7126
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שבת'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שֶׁבֶת'}}
#
# 343
# ...
#
# 428
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 429
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 430
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 431
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 432
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 433
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 434
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 435
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 436
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 437
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 438
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 439
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 440
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 441
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 442
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 443
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 444
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 445
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 446
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 447
# L75622
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'אנטומיה'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'אָנָטוֹמְיָה'}}
#
# 448
# L10101
# {'fr': {'language': 'fr', 'value': 'rue'}}
#
# 449
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 450
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 451
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 452
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 453
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 454
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 455
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 456
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 457
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 458
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 459
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 460
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 461
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 462
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 463
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 464
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 465
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 466
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 467
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 468
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 469
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 470
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 471
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 472
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 473
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 474
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 475
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 476
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 477
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 478
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 479
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 480
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 481
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 482
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 483
# L19635
# {'pt': {'language': 'pt', 'value': 'abolir'}}
#
# 484
# L208770
# {'fr': {'language': 'fr', 'value': 'sèche-cheveux'}}
#
# 485
# L409107
# {'en-gb': {'language': 'en-gb', 'value': 'polarisation'}, 'en-x-Q30': {'language': 'en-x-Q30', 'value': 'polarization'}}
#
# 486
# L409107
# {'en-gb': {'language': 'en-gb', 'value': 'polarisation'}, 'en-x-Q30': {'language': 'en-x-Q30', 'value': 'polarization'}}
#
# 487
# L2
# {'en': {'language': 'en', 'value': 'first'}}
#
# 488
# L8
# {'en': {'language': 'en', 'value': 'late'}, 'en-x-Q1337': {'language': 'en-x-Q1337', 'value': 'l8'}}
#
# 489
# L8
# {'en': {'language': 'en', 'value': 'late'}, 'en-x-Q1337': {'language': 'en-x-Q1337', 'value': 'l8'}}
#
# 490
# L8
# {'en': {'language': 'en', 'value': 'late'}, 'en-x-Q1337': {'language': 'en-x-Q1337', 'value': 'l8'}}
#
# 491
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 492
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 493
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 494
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 495
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 496
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 497
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 498
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 499
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 500
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 501
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 502
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 503
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 504
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 505
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 506
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 507
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 508
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 509
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 510
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 511
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 512
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 513
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 514
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 515
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 516
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 517
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 518
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 519
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 520
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 521
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 522
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 523
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 524
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 525
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 526
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 527
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 528
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 529
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 530
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 531
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 532
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 533
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 534
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 535
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 536
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 537
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 538
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 539
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 540
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 541
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 542
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 543
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 544
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 545
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 546
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 547
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 548
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 549
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 550
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 551
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 552
# L384
# {'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'שלום'}, 'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'שָׁלוֹם'}}
#
# 553
# L2212
# {'he-x-Q21283070': {'language': 'he-x-Q21283070', 'value': 'דִּיגִיטָלִי'}, 'he-x-Q2975864': {'language': 'he-x-Q2975864', 'value': 'דיגיטלי'}}
#
# 554
# L10291
# {'fr': {'language': 'fr', 'value': 'battement'}}
#
# 555
# L11729
# {'es-419': {'language': 'es-419', 'value': 'cabe'}}
#
# 556
# L11729
# {'es-419': {'language': 'es-419', 'value': 'cabe'}}
#
# 557
# L18879
# {'fr': {'language': 'fr', 'value': 'accident'}}
#
# 558
# L34280
# {'pt': {'language': 'pt', 'value': 'gato'}, 'pt-br': {'language': 'pt-br', 'value': 'gato'}}
#
# 559
# L34280
# {'pt': {'language': 'pt', 'value': 'gato'}, 'pt-br': {'language': 'pt-br', 'value': 'gato'}}
#
# 560
# L34280
# {'pt': {'language': 'pt', 'value': 'gato'}, 'pt-br': {'language': 'pt-br', 'value': 'gato'}}
#
# 561
# L34280
# {'pt': {'language': 'pt', 'value': 'gato'}, 'pt-br': {'language': 'pt-br', 'value': 'gato'}}
#
# 562
# L252247
# {'en': {'language': 'en', 'value': 'Junior'}}
#
# 563
# L252247
# {'en': {'language': 'en', 'value': 'Junior'}}
#
# 405,168 Lexemes total, 331,937 used

# %% [markdown]
# Now we create the progress report for the given languages.

# %%
import urllib

def load_filter(language):
    try:
        page = urllib.request.urlopen( 'https://www.wikidata.org/wiki/Wikidata:Lexicographical_coverage/Filter/' + language + '?action=raw')
        text = page.read().decode('utf-8')
        lines = text.split('\n')
        filtered = set()
        for line in lines:
            if not (line.startswith('*') or line.startswith('#')):
                continue
            _, word = line.split(' ', 1)
            filtered.add(word.lower())
        return filtered
    except:
        print('Could not load filter page for ' + language)
        return []

for language in languages:
    filtered = load_filter(language)
    forms = set()
    for line in open('formlist-' + language + '.txt'):
        form = line.strip().lower()
        form = form.replace('.', '')
        forms.add(form)

    tokencount = 0
    wordcount = 0
    coveredtokens = 0
    uncoveredtokens = 0
    coveredwords = 0
    uncoveredwords = 0
    for line in open('wordlist-' + language + '.txt'):
        word, _, count = line.strip().rpartition(' ')
        count = int(count)
        tokencount += count
        wordcount += 1
        if word in forms or word in filtered:
            coveredwords += 1
            coveredtokens += count
        else:
            uncoveredwords += 1
            uncoveredtokens += count

    print('== {{{{Q|{}}}}} ({}) =='.format(qmap[language], language))
    print('<table><tr><td>')
    print('* Forms in Wikidata: {:,}'.format(len(forms)))
    print('* Forms in Wikipedia (w/ 10+ tokens): {:,}'.format(wordcount))
    print('* Tokens (10+ only): {:,}'.format(tokencount))
    print('* Covered forms: {:,} ({:.1%})'.format(coveredwords, 1.0*coveredwords/wordcount))
    print('* Missing forms:  {:,} ({:.1%})'.format(uncoveredwords, 1.0*uncoveredwords/wordcount))
    print('* Covered tokens: {:,} ({:.1%})'.format(coveredtokens, 1.0*coveredtokens/tokencount))
    print('* Missing tokens: {:,} ({:.1%})'.format(uncoveredtokens, 1.0*uncoveredtokens/tokencount))
    print('* [[Wikidata:Lexicographical_coverage/Missing/{}|Most frequent missing forms]]'.format(language))
    print('</td><td>')
    print('{{{{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1={},{}}}}}'.format(
        coveredwords,
        uncoveredwords
    ))
    print('</td><td>')
    print('{{{{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1={},{}}}}}'.format(
        coveredtokens,
        uncoveredtokens
    ))
    print('</td></td></table>')
    print('')
# Out:
# Could not load filter page for ar
# == {{Q|Q13955}} (ar) ==
# <table><tr><td>
# * Forms in Wikidata: 202
# * Forms in Wikipedia (w/ 10+ tokens): 248,809
# * Tokens (10+ only): 69,904,516
# * Covered forms: 35 (0.0%)
# * Missing forms:  248,774 (100.0%)
# * Covered tokens: 245,740 (0.4%)
# * Missing tokens: 69,658,776 (99.6%)
# * [[Wikidata:Lexicographical_coverage/Missing/ar|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=35,248774}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=245740,69658776}}
# </td></td></table>
#
# Could not load filter page for bg
# == {{Q|Q7918}} (bg) ==
# <table><tr><td>
# * Forms in Wikidata: 166
# * Forms in Wikipedia (w/ 10+ tokens): 124,069
# * Tokens (10+ only): 33,507,484
# * Covered forms: 152 (0.1%)
# * Missing forms:  123,917 (99.9%)
# * Covered tokens: 347,412 (1.0%)
# * Missing tokens: 33,160,072 (99.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/bg|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=152,123917}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=347412,33160072}}
# </td></td></table>
#
# Could not load filter page for ca
# == {{Q|Q7026}} (ca) ==
# <table><tr><td>
# * Forms in Wikidata: 116
# * Forms in Wikipedia (w/ 10+ tokens): 182,535
# * Tokens (10+ only): 109,381,764
# * Covered forms: 97 (0.1%)
# * Missing forms:  182,438 (99.9%)
# * Covered tokens: 11,036,460 (10.1%)
# * Missing tokens: 98,345,304 (89.9%)
# * [[Wikidata:Lexicographical_coverage/Missing/ca|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=97,182438}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=11036460,98345304}}
# </td></td></table>
#
# Could not load filter page for cs
# == {{Q|Q9056}} (cs) ==
# <table><tr><td>
# * Forms in Wikidata: 106,648
# * Forms in Wikipedia (w/ 10+ tokens): 273,215
# * Tokens (10+ only): 73,639,616
# * Covered forms: 26,526 (9.7%)
# * Missing forms:  246,689 (90.3%)
# * Covered tokens: 32,663,946 (44.4%)
# * Missing tokens: 40,975,670 (55.6%)
# * [[Wikidata:Lexicographical_coverage/Missing/cs|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=26526,246689}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=32663946,40975670}}
# </td></td></table>
#
# Could not load filter page for da
# == {{Q|Q9035}} (da) ==
# <table><tr><td>
# * Forms in Wikidata: 31,670
# * Forms in Wikipedia (w/ 10+ tokens): 112,469
# * Tokens (10+ only): 31,303,226
# * Covered forms: 17,096 (15.2%)
# * Missing forms:  95,373 (84.8%)
# * Covered tokens: 24,553,257 (78.4%)
# * Missing tokens: 6,749,969 (21.6%)
# * [[Wikidata:Lexicographical_coverage/Missing/da|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=17096,95373}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=24553257,6749969}}
# </td></td></table>
#
# == {{Q|Q188}} (de) ==
# <table><tr><td>
# * Forms in Wikidata: 21,654
# * Forms in Wikipedia (w/ 10+ tokens): 1,035,287
# * Tokens (10+ only): 609,589,775
# * Covered forms: 15,735 (1.5%)
# * Missing forms:  1,019,552 (98.5%)
# * Covered tokens: 383,725,271 (62.9%)
# * Missing tokens: 225,864,504 (37.1%)
# * [[Wikidata:Lexicographical_coverage/Missing/de|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=15735,1019552}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=383725271,225864504}}
# </td></td></table>
#
# Could not load filter page for el
# == {{Q|Q9129}} (el) ==
# <table><tr><td>
# * Forms in Wikidata: 9
# * Forms in Wikipedia (w/ 10+ tokens): 132,176
# * Tokens (10+ only): 40,493,491
# * Covered forms: 9 (0.0%)
# * Missing forms:  132,167 (100.0%)
# * Covered tokens: 4,024 (0.0%)
# * Missing tokens: 40,489,467 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/el|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=9,132167}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=4024,40489467}}
# </td></td></table>
#
# == {{Q|Q1860}} (en) ==
# <table><tr><td>
# * Forms in Wikidata: 64,474
# * Forms in Wikipedia (w/ 10+ tokens): 963,849
# * Tokens (10+ only): 1,529,657,229
# * Covered forms: 41,693 (4.3%)
# * Missing forms:  922,156 (95.7%)
# * Covered tokens: 1,345,671,741 (88.0%)
# * Missing tokens: 183,985,488 (12.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/en|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=41693,922156}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=1345671741,183985488}}
# </td></td></table>
#
# Could not load filter page for es
# == {{Q|Q1321}} (es) ==
# <table><tr><td>
# * Forms in Wikidata: 4,076
# * Forms in Wikipedia (w/ 10+ tokens): 407,203
# * Tokens (10+ only): 410,849,972
# * Covered forms: 3,337 (0.8%)
# * Missing forms:  403,866 (99.2%)
# * Covered tokens: 185,831,783 (45.2%)
# * Missing tokens: 225,018,189 (54.8%)
# * [[Wikidata:Lexicographical_coverage/Missing/es|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=3337,403866}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=185831783,225018189}}
# </td></td></table>
#
# Could not load filter page for et
# == {{Q|Q9072}} (et) ==
# <table><tr><td>
# * Forms in Wikidata: 1,606,320
# * Forms in Wikipedia (w/ 10+ tokens): 125,385
# * Tokens (10+ only): 17,193,400
# * Covered forms: 65,713 (52.4%)
# * Missing forms:  59,672 (47.6%)
# * Covered tokens: 13,516,078 (78.6%)
# * Missing tokens: 3,677,322 (21.4%)
# * [[Wikidata:Lexicographical_coverage/Missing/et|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=65713,59672}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=13516078,3677322}}
# </td></td></table>
#
# Could not load filter page for fa
# == {{Q|Q9168}} (fa) ==
# <table><tr><td>
# * Forms in Wikidata: 44
# * Forms in Wikipedia (w/ 10+ tokens): 105,204
# * Tokens (10+ only): 44,537,319
# * Covered forms: 27 (0.0%)
# * Missing forms:  105,177 (100.0%)
# * Covered tokens: 111,378 (0.3%)
# * Missing tokens: 44,425,941 (99.7%)
# * [[Wikidata:Lexicographical_coverage/Missing/fa|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=27,105177}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=111378,44425941}}
# </td></td></table>
#
# Could not load filter page for fi
# == {{Q|Q1412}} (fi) ==
# <table><tr><td>
# * Forms in Wikidata: 7,066
# * Forms in Wikipedia (w/ 10+ tokens): 280,697
# * Tokens (10+ only): 48,016,979
# * Covered forms: 4,496 (1.6%)
# * Missing forms:  276,201 (98.4%)
# * Covered tokens: 11,621,572 (24.2%)
# * Missing tokens: 36,395,407 (75.8%)
# * [[Wikidata:Lexicographical_coverage/Missing/fi|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=4496,276201}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=11621572,36395407}}
# </td></td></table>
#
# Could not load filter page for fr
# == {{Q|Q150}} (fr) ==
# <table><tr><td>
# * Forms in Wikidata: 17,572
# * Forms in Wikipedia (w/ 10+ tokens): 509,133
# * Tokens (10+ only): 480,816,389
# * Covered forms: 15,415 (3.0%)
# * Missing forms:  493,718 (97.0%)
# * Covered tokens: 356,823,240 (74.2%)
# * Missing tokens: 123,993,149 (25.8%)
# * [[Wikidata:Lexicographical_coverage/Missing/fr|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=15415,493718}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=356823240,123993149}}
# </td></td></table>
#
# Could not load filter page for he
# == {{Q|Q9288}} (he) ==
# <table><tr><td>
# * Forms in Wikidata: 324,189
# * Forms in Wikipedia (w/ 10+ tokens): 249,040
# * Tokens (10+ only): 77,424,809
# * Covered forms: 53,750 (21.6%)
# * Missing forms:  195,290 (78.4%)
# * Covered tokens: 35,041,363 (45.3%)
# * Missing tokens: 42,383,446 (54.7%)
# * [[Wikidata:Lexicographical_coverage/Missing/he|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=53750,195290}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=35041363,42383446}}
# </td></td></table>
#
# Could not load filter page for hi
# == {{Q|Q11051}} (hi) ==
# <table><tr><td>
# * Forms in Wikidata: 151
# * Forms in Wikipedia (w/ 10+ tokens): 54,671
# * Tokens (10+ only): 18,940,269
# * Covered forms: 106 (0.2%)
# * Missing forms:  54,565 (99.8%)
# * Covered tokens: 2,859,937 (15.1%)
# * Missing tokens: 16,080,332 (84.9%)
# * [[Wikidata:Lexicographical_coverage/Missing/hi|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=106,54565}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=2859937,16080332}}
# </td></td></table>
#
# Could not load filter page for hr
# == {{Q|Q6654}} (hr) ==
# <table><tr><td>
# * Forms in Wikidata: 54
# * Forms in Wikipedia (w/ 10+ tokens): 137,158
# * Tokens (10+ only): 28,734,051
# * Covered forms: 52 (0.0%)
# * Missing forms:  137,106 (100.0%)
# * Covered tokens: 1,311,223 (4.6%)
# * Missing tokens: 27,422,828 (95.4%)
# * [[Wikidata:Lexicographical_coverage/Missing/hr|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=52,137106}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=1311223,27422828}}
# </td></td></table>
#
# Could not load filter page for hu
# == {{Q|Q9067}} (hu) ==
# <table><tr><td>
# * Forms in Wikidata: 131
# * Forms in Wikipedia (w/ 10+ tokens): 274,944
# * Tokens (10+ only): 66,221,994
# * Covered forms: 76 (0.0%)
# * Missing forms:  274,868 (100.0%)
# * Covered tokens: 133,408 (0.2%)
# * Missing tokens: 66,088,586 (99.8%)
# * [[Wikidata:Lexicographical_coverage/Missing/hu|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=76,274868}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=133408,66088586}}
# </td></td></table>
#
# Could not load filter page for id
# == {{Q|Q9240}} (id) ==
# <table><tr><td>
# * Forms in Wikidata: 13
# * Forms in Wikipedia (w/ 10+ tokens): 100,253
# * Tokens (10+ only): 40,761,652
# * Covered forms: 6 (0.0%)
# * Missing forms:  100,247 (100.0%)
# * Covered tokens: 111,960 (0.3%)
# * Missing tokens: 40,649,692 (99.7%)
# * [[Wikidata:Lexicographical_coverage/Missing/id|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=6,100247}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=111960,40649692}}
# </td></td></table>
#
# Could not load filter page for it
# == {{Q|Q652}} (it) ==
# <table><tr><td>
# * Forms in Wikidata: 552
# * Forms in Wikipedia (w/ 10+ tokens): 362,088
# * Tokens (10+ only): 285,803,701
# * Covered forms: 451 (0.1%)
# * Missing forms:  361,637 (99.9%)
# * Covered tokens: 90,843,445 (31.8%)
# * Missing tokens: 194,960,256 (68.2%)
# * [[Wikidata:Lexicographical_coverage/Missing/it|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=451,361637}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=90843445,194960256}}
# </td></td></table>
#
# Could not load filter page for ko
# == {{Q|Q9176}} (ko) ==
# <table><tr><td>
# * Forms in Wikidata: 24
# * Forms in Wikipedia (w/ 10+ tokens): 291,154
# * Tokens (10+ only): 34,066,055
# * Covered forms: 22 (0.0%)
# * Missing forms:  291,132 (100.0%)
# * Covered tokens: 74,177 (0.2%)
# * Missing tokens: 33,991,878 (99.8%)
# * [[Wikidata:Lexicographical_coverage/Missing/ko|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=22,291132}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=74177,33991878}}
# </td></td></table>
#
# Could not load filter page for lt
# == {{Q|Q9083}} (lt) ==
# <table><tr><td>
# * Forms in Wikidata: 34
# * Forms in Wikipedia (w/ 10+ tokens): 96,810
# * Tokens (10+ only): 13,279,874
# * Covered forms: 13 (0.0%)
# * Missing forms:  96,797 (100.0%)
# * Covered tokens: 16,312 (0.1%)
# * Missing tokens: 13,263,562 (99.9%)
# * [[Wikidata:Lexicographical_coverage/Missing/lt|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=13,96797}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=16312,13263562}}
# </td></td></table>
#
# == {{Q|Q9078}} (lv) ==
# <table><tr><td>
# * Forms in Wikidata: 38
# * Forms in Wikipedia (w/ 10+ tokens): 61,009
# * Tokens (10+ only): 8,038,325
# * Covered forms: 36 (0.1%)
# * Missing forms:  60,973 (99.9%)
# * Covered tokens: 264,751 (3.3%)
# * Missing tokens: 7,773,574 (96.7%)
# * [[Wikidata:Lexicographical_coverage/Missing/lv|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=36,60973}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=264751,7773574}}
# </td></td></table>
#
# == {{Q|Q9237}} (ms) ==
# <table><tr><td>
# * Forms in Wikidata: 410
# * Forms in Wikipedia (w/ 10+ tokens): 51,390
# * Tokens (10+ only): 16,488,858
# * Covered forms: 343 (0.7%)
# * Missing forms:  51,047 (99.3%)
# * Covered tokens: 2,967,217 (18.0%)
# * Missing tokens: 13,521,641 (82.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/ms|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=343,51047}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=2967217,13521641}}
# </td></td></table>
#
# Could not load filter page for nl
# == {{Q|Q7411}} (nl) ==
# <table><tr><td>
# * Forms in Wikidata: 189
# * Forms in Wikipedia (w/ 10+ tokens): 260,355
# * Tokens (10+ only): 132,085,109
# * Covered forms: 151 (0.1%)
# * Missing forms:  260,204 (99.9%)
# * Covered tokens: 25,230,913 (19.1%)
# * Missing tokens: 106,854,196 (80.9%)
# * [[Wikidata:Lexicographical_coverage/Missing/nl|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=151,260204}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=25230913,106854196}}
# </td></td></table>
#
# Could not load filter page for no
# == {{Q|Q9043}} (no) ==
# <table><tr><td>
# * Forms in Wikidata: 0
# * Forms in Wikipedia (w/ 10+ tokens): 157,110
# * Tokens (10+ only): 50,156,203
# * Covered forms: 0 (0.0%)
# * Missing forms:  157,110 (100.0%)
# * Covered tokens: 0 (0.0%)
# * Missing tokens: 50,156,203 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/no|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=0,157110}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=0,50156203}}
# </td></td></table>
#
# Could not load filter page for pl
# == {{Q|Q809}} (pl) ==
# <table><tr><td>
# * Forms in Wikidata: 15,167
# * Forms in Wikipedia (w/ 10+ tokens): 347,729
# * Tokens (10+ only): 118,603,892
# * Covered forms: 5,511 (1.6%)
# * Missing forms:  342,218 (98.4%)
# * Covered tokens: 37,597,183 (31.7%)
# * Missing tokens: 81,006,709 (68.3%)
# * [[Wikidata:Lexicographical_coverage/Missing/pl|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=5511,342218}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=37597183,81006709}}
# </td></td></table>
#
# Could not load filter page for pt
# == {{Q|Q5146}} (pt) ==
# <table><tr><td>
# * Forms in Wikidata: 230
# * Forms in Wikipedia (w/ 10+ tokens): 216,977
# * Tokens (10+ only): 159,851,092
# * Covered forms: 220 (0.1%)
# * Missing forms:  216,757 (99.9%)
# * Covered tokens: 40,799,577 (25.5%)
# * Missing tokens: 119,051,515 (74.5%)
# * [[Wikidata:Lexicographical_coverage/Missing/pt|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=220,216757}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=40799577,119051515}}
# </td></td></table>
#
# Could not load filter page for ro
# == {{Q|Q7913}} (ro) ==
# <table><tr><td>
# * Forms in Wikidata: 26
# * Forms in Wikipedia (w/ 10+ tokens): 122,714
# * Tokens (10+ only): 41,686,740
# * Covered forms: 23 (0.0%)
# * Missing forms:  122,691 (100.0%)
# * Covered tokens: 337,184 (0.8%)
# * Missing tokens: 41,349,556 (99.2%)
# * [[Wikidata:Lexicographical_coverage/Missing/ro|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=23,122691}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=337184,41349556}}
# </td></td></table>
#
# Could not load filter page for ru
# == {{Q|Q7737}} (ru) ==
# <table><tr><td>
# * Forms in Wikidata: 909,861
# * Forms in Wikipedia (w/ 10+ tokens): 737,316
# * Tokens (10+ only): 293,969,821
# * Covered forms: 135,100 (18.3%)
# * Missing forms:  602,216 (81.7%)
# * Covered tokens: 155,780,357 (53.0%)
# * Missing tokens: 138,189,464 (47.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/ru|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=135100,602216}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=155780357,138189464}}
# </td></td></table>
#
# Could not load filter page for sk
# == {{Q|Q9058}} (sk) ==
# <table><tr><td>
# * Forms in Wikidata: 67,881
# * Forms in Wikipedia (w/ 10+ tokens): 112,477
# * Tokens (10+ only): 18,309,458
# * Covered forms: 31,248 (27.8%)
# * Missing forms:  81,229 (72.2%)
# * Covered tokens: 10,976,657 (60.0%)
# * Missing tokens: 7,332,801 (40.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/sk|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=31248,81229}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=10976657,7332801}}
# </td></td></table>
#
# Could not load filter page for sl
# == {{Q|Q9063}} (sl) ==
# <table><tr><td>
# * Forms in Wikidata: 2
# * Forms in Wikipedia (w/ 10+ tokens): 108,154
# * Tokens (10+ only): 19,956,790
# * Covered forms: 2 (0.0%)
# * Missing forms:  108,152 (100.0%)
# * Covered tokens: 2,134 (0.0%)
# * Missing tokens: 19,954,656 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/sl|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=2,108152}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=2134,19954656}}
# </td></td></table>
#
# Could not load filter page for sr
# == {{Q|Q9299}} (sr) ==
# <table><tr><td>
# * Forms in Wikidata: 9
# * Forms in Wikipedia (w/ 10+ tokens): 186,254
# * Tokens (10+ only): 42,614,833
# * Covered forms: 1 (0.0%)
# * Missing forms:  186,253 (100.0%)
# * Covered tokens: 682 (0.0%)
# * Missing tokens: 42,614,151 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/sr|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=1,186253}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=682,42614151}}
# </td></td></table>
#
# == {{Q|Q9027}} (sv) ==
# <table><tr><td>
# * Forms in Wikidata: 145,092
# * Forms in Wikipedia (w/ 10+ tokens): 224,857
# * Tokens (10+ only): 72,905,148
# * Covered forms: 39,917 (17.8%)
# * Missing forms:  184,940 (82.2%)
# * Covered tokens: 55,842,467 (76.6%)
# * Missing tokens: 17,062,681 (23.4%)
# * [[Wikidata:Lexicographical_coverage/Missing/sv|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=39917,184940}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=55842467,17062681}}
# </td></td></table>
#
# Could not load filter page for th
# == {{Q|Q9217}} (th) ==
# <table><tr><td>
# * Forms in Wikidata: 3
# * Forms in Wikipedia (w/ 10+ tokens): 27,643
# * Tokens (10+ only): 2,110,587
# * Covered forms: 2 (0.0%)
# * Missing forms:  27,641 (100.0%)
# * Covered tokens: 634 (0.0%)
# * Missing tokens: 2,109,953 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/th|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=2,27641}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=634,2109953}}
# </td></td></table>
#
# Could not load filter page for tl
# == {{Q|Q34057}} (tl) ==
# <table><tr><td>
# * Forms in Wikidata: 1
# * Forms in Wikipedia (w/ 10+ tokens): 21,065
# * Tokens (10+ only): 3,648,071
# * Covered forms: 1 (0.0%)
# * Missing forms:  21,064 (100.0%)
# * Covered tokens: 1,092 (0.0%)
# * Missing tokens: 3,646,979 (100.0%)
# * [[Wikidata:Lexicographical_coverage/Missing/tl|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=1,21064}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=1092,3646979}}
# </td></td></table>
#
# Could not load filter page for tr
# == {{Q|Q256}} (tr) ==
# <table><tr><td>
# * Forms in Wikidata: 33
# * Forms in Wikipedia (w/ 10+ tokens): 153,117
# * Tokens (10+ only): 30,303,829
# * Covered forms: 32 (0.0%)
# * Missing forms:  153,085 (100.0%)
# * Covered tokens: 156,644 (0.5%)
# * Missing tokens: 30,147,185 (99.5%)
# * [[Wikidata:Lexicographical_coverage/Missing/tr|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=32,153085}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=156644,30147185}}
# </td></td></table>
#
# Could not load filter page for uk
# == {{Q|Q8798}} (uk) ==
# <table><tr><td>
# * Forms in Wikidata: 735
# * Forms in Wikipedia (w/ 10+ tokens): 390,930
# * Tokens (10+ only): 115,784,608
# * Covered forms: 544 (0.1%)
# * Missing forms:  390,386 (99.9%)
# * Covered tokens: 4,257,784 (3.7%)
# * Missing tokens: 111,526,824 (96.3%)
# * [[Wikidata:Lexicographical_coverage/Missing/uk|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=544,390386}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=4257784,111526824}}
# </td></td></table>
#
# Could not load filter page for vi
# == {{Q|Q9199}} (vi) ==
# <table><tr><td>
# * Forms in Wikidata: 7
# * Forms in Wikipedia (w/ 10+ tokens): 65,293
# * Tokens (10+ only): 75,906,401
# * Covered forms: 5 (0.0%)
# * Missing forms:  65,288 (100.0%)
# * Covered tokens: 46,628 (0.1%)
# * Missing tokens: 75,859,773 (99.9%)
# * [[Wikidata:Lexicographical_coverage/Missing/vi|Most frequent missing forms]]
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Forms|x=Covered,Missing|y1=5,65288}}
# </td><td>
# {{Graph:Chart|width=100|type=pie|legend=Tokens|x=Covered,Missing|y1=46628,75859773}}
# </td></td></table>

# %% [markdown]
# And finally the list of the most frequent missing Forms.

# %%
for language in languages:
    top = 1000
    forms = set()
    for line in open('formlist-' + language + '.txt'):
        forms.add(line.strip().lower())

    output = open('missing-' + language + '.txt', 'w')

    filtered = load_filter(language)

    for line in open('wordlist-' + language + '.txt'):
        word, _, count = line.strip().rpartition(' ')
        word = word.lower()

        count = int(count)
        if word in forms or word in filtered:
            pass
        else:
            top -= 1
            if top < 0:
                break
            output.write('# {} ({:,})\n'.format(word, count))
    
    output.close()
    print('Stored in missing-{}.txt'.format(language))
# Out:
# Could not load filter page for ar
# Stored in missing-ar.txt
# Could not load filter page for bg
# Stored in missing-bg.txt
# Could not load filter page for ca
# Stored in missing-ca.txt
# Could not load filter page for cs
# Stored in missing-cs.txt
# Could not load filter page for da
# Stored in missing-da.txt
# Stored in missing-de.txt
# Could not load filter page for el
# Stored in missing-el.txt
# Stored in missing-en.txt
# Could not load filter page for es
# Stored in missing-es.txt
# Could not load filter page for et
# Stored in missing-et.txt
# Could not load filter page for fa
# Stored in missing-fa.txt
# Could not load filter page for fi
# Stored in missing-fi.txt
# Could not load filter page for fr
# Stored in missing-fr.txt
# Could not load filter page for he
# Stored in missing-he.txt
# Could not load filter page for hi
# Stored in missing-hi.txt
# Could not load filter page for hr
# Stored in missing-hr.txt
# Could not load filter page for hu
# Stored in missing-hu.txt
# Could not load filter page for id
# Stored in missing-id.txt
# Could not load filter page for it
# Stored in missing-it.txt
# Could not load filter page for ko
# Stored in missing-ko.txt
# Could not load filter page for lt
# Stored in missing-lt.txt
# Stored in missing-lv.txt
# Stored in missing-ms.txt
# Could not load filter page for nl
# Stored in missing-nl.txt
# Could not load filter page for no
# Stored in missing-no.txt
# Could not load filter page for pl
# Stored in missing-pl.txt
# Could not load filter page for pt
# Stored in missing-pt.txt
# Could not load filter page for ro
# Stored in missing-ro.txt
# Could not load filter page for ru
# Stored in missing-ru.txt
# Could not load filter page for sk
# Stored in missing-sk.txt
# Could not load filter page for sl
# Stored in missing-sl.txt
# Could not load filter page for sr
# Stored in missing-sr.txt
# Stored in missing-sv.txt
# Could not load filter page for th
# Stored in missing-th.txt
# Could not load filter page for tl
# Stored in missing-tl.txt
# Could not load filter page for tr
# Stored in missing-tr.txt
# Could not load filter page for uk
# Stored in missing-uk.txt
# Could not load filter page for vi
# Stored in missing-vi.txt
